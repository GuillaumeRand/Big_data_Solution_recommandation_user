# %%
import seaborn as sns
import matplotlib.pyplot as plt

# %%
# %run specific_customer.py

# Afficher les résultats
print(top_10_clients())
# Out:
#       CLI_ID  counts
# 0  975127123     834
# 1  989177106     608
# 2  994357808     560
# 3  988071368     525
# 4  992282539     502
# 5  985653794     426
# 6  991203536     413
# 7  976706610     409
# 8  964063529     398
# 9  974961069     379

# %%
id_client = input("Entrez l'ID du client :")
# %run specific_customer.py
init_df_client(id_client)

# %%
cross_tab = cross_sales(id_client)

# Créer un graphique de chaleur en utilisant seaborn
if len(cross_tab) > 15:
    fig, ax = plt.subplots(figsize=(15,15))  
    sns.heatmap(cross_tab, linewidth=.45, square=True, ax=ax)
else:
    sns.heatmap(cross_tab, linewidth=.45, square=True)

plt.show()

# %%
df_filtered_month = customer_purchases_by_month(id_client)

# Tracer un graphique des dépenses totales par mois
plt.bar(df_filtered_month['MOIS_VENTE'], df_filtered_month['PRIX_NET'])
plt.xlabel('Mois')
plt.ylabel('Dépenses totales')
plt.title('Dépenses totales par mois pour le client {}'.format(id_client))
plt.xticks(rotation=45)
plt.show()

# %%
df_filtered = customer_purchases_evol(id_client)
# Tracer un graphique de tendance des dépenses totales par mois
plt.plot(df_filtered['MOIS_VENTE'], df_filtered['PRIX_NET'], '-o')
plt.xlabel('Mois')
plt.ylabel('Dépenses totales')
plt.title('Tendance des dépenses totales pour le client {}'.format(id_client))
plt.xticks(rotation=45)
plt.show()

# %%
df_average_by_category = customer_purchases_by_category(id_client)

# Tracer un graphique des dépenses moyennes par catégorie
df_average_by_category.plot(kind='bar', figsize=(10, 6))
plt.xlabel('Famille')
plt.ylabel('Dépense moyenne')
plt.title('Dépenses moyennes par famille pour le client {}'.format(id_client))
plt.show()
# Out:
# D:\Users\Documents\Dev\Python\T-DAT-901-MPL_7\specific_customer.py:79: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.

# %%
df_average_price_by_ticket = average_price_by_ticket(id_client)
# Affichage de la dépense moyenne
print("La dépense moyenne par ticket pour le client {} est de : ".format(id_client), df_average_price_by_ticket)
# Out:
# La dépense moyenne par ticket pour le client 1490281 est de :  18.4

# %%
most_bought_products = most_bought_products(id_client)
# Affichage des produits les plus achetés

print("Les produits les plus achetés par le client {} sont : ".format(id_client))
print(most_bought_products)
# Out:
# Les produits les plus achetés par le client 1490281 sont :
#                            LIBELLE  counts
# 0    GD JDM4 PAMPLEMOUSSE FL 200ML       2
# 1  CR JR PARF BIO.SPE AC.SENT.50ML       1
# 2    EAU MICELLAIRE 3 THES FL200ML       1
# 3           GD JDM4 TIARE FL 200ML       1
